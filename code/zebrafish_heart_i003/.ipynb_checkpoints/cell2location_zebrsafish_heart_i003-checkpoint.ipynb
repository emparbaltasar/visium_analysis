# %% [markdown]
# # Loading packages

# %%
import sys
import scanpy as sc
import anndata
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl
import os
import cell2location
import scvi

from matplotlib import rcParams
rcParams['pdf.fonttype'] = 42 # enables correct plotting of text for PDFs
# Out:
# Global seed set to 0

# %%
os.getcwd()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Input In [31], in <cell line: 1>()
# ----> 1 os.getcwd()
#
# FileNotFoundError: [Errno 2] No such file or directory

# %%
#Change directory to visium-pipeline-development
os.chdir("../..")

# %%
os.getcwd()
# Out:
# '/Volumes/T7/SCD/projects/visium-pipeline-development'

# %% [markdown]
# First, let's define where we save the results of our analysis:

# %%
results_folder = './output/cell2location/zebrafish_heart/SCD-VI-i003'

# create paths and names to results folders for reference regression and cell2location models
ref_run_name = f'{results_folder}/reference_signatures'
run_name = f'{results_folder}/cell2location_map'

# %% [markdown]
# # Loading Visium and scRNA-seq reference data

# %% [markdown]
# First let’s read spatial Visium data from 10X Space Ranger output. We rename genes to ENSEMBL ID for correct matching between single cell and spatial data - so you can ignore the scanpy suggestion to call .var_names_make_unique.

# %%
adata_vis = sc.read("./output/processed_data/SCD-VI-i003/SCD-VI-i003_subset.h5ad")
adata_vis
# Out:
# AnnData object with n_obs × n_vars = 318 × 32520
#     obs: 'orig.ident', 'nCount_Spatial', 'nFeature_Spatial'
#     var: '_index', 'features'

# %%
adata_vis.var
# Out:
#                 _index         features
# 0               ptpn12           ptpn12
# 1                phtf2            phtf2
# 2              phtf2.1          phtf2.1
# 3           CU856344.1       CU856344.1
# 4      si:zfos-932h1.3  si:zfos-932h1.3
# ...                ...              ...
# 32515   CABZ01110379.1   CABZ01110379.1
# 32516   CABZ01054289.1   CABZ01054289.1
# 32517   CABZ01109604.1   CABZ01109604.1
# 32518            LAMP5            LAMP5
# 32519              RHO              RHO
#
# [32520 rows x 2 columns]

# %%
adata_vis.var.columns = ['index','features']
adata_vis.var
# Out:
#                  index         features
# 0               ptpn12           ptpn12
# 1                phtf2            phtf2
# 2              phtf2.1          phtf2.1
# 3           CU856344.1       CU856344.1
# 4      si:zfos-932h1.3  si:zfos-932h1.3
# ...                ...              ...
# 32515   CABZ01110379.1   CABZ01110379.1
# 32516   CABZ01054289.1   CABZ01054289.1
# 32517   CABZ01109604.1   CABZ01109604.1
# 32518            LAMP5            LAMP5
# 32519              RHO              RHO
#
# [32520 rows x 2 columns]

# %%
adata_vis.var.set_index('index', drop=True, inplace=True)

# %%
adata_vis.var
# Out:
#                         features
# index
# ptpn12                    ptpn12
# phtf2                      phtf2
# phtf2.1                  phtf2.1
# CU856344.1            CU856344.1
# si:zfos-932h1.3  si:zfos-932h1.3
# ...                          ...
# CABZ01110379.1    CABZ01110379.1
# CABZ01054289.1    CABZ01054289.1
# CABZ01109604.1    CABZ01109604.1
# LAMP5                      LAMP5
# RHO                          RHO
#
# [32520 rows x 1 columns]

# %% [markdown]
# Mitochondia-encoded genes (gene names start with prefix mt- or MT-) are irrelevant for spatial mapping because their expression represents technical artifacts in the single cell and nucleus data rather than biological abundance of mitochondria. Yet these genes compose 15-40% of mRNA in each location. Hence, to avoid mapping artifacts we strongly recommend removing mitochondrial genes.

# %%
# find mitochondria-encoded (MT) genes
adata_vis.var['MT_gene'] = [gene.startswith('mt-') for gene in adata_vis.var['features']]

# remove MT genes for spatial mapping (keeping their counts in the object)
adata_vis.obsm['MT'] = adata_vis[:, adata_vis.var['MT_gene'].values].X.toarray()
adata_vis = adata_vis[:, ~adata_vis.var['MT_gene'].values]

# %% [markdown]
# Now we load the scRNA-seq data:

# %%
adata_ref = sc.read("./output/processed_data/zebrafish_heart_scrnaseq.h5ad")

# %%
adata_ref
# Out:
# AnnData object with n_obs × n_vars = 73858 × 23466
#     obs: 'orig.ident', 'nCount_originalexp', 'nFeature_originalexp', 'time', 'morphine', 'AV', 'inhib', 'plot.ident2', 'nCount_RNA', 'nFeature_RNA'
#     var: 'vst.mean', 'vst.variance', 'vst.variance.expected', 'vst.variance.standardized', 'vst.variable'

# %%
adata_ref.var
# Out:
#             vst.mean  vst.variance  vst.variance.expected  \
# dusp16      0.014383      0.015363               0.018556
# crebl2      0.031193      0.033800               0.042161
# gpr19       0.002250      0.002264               0.002687
# tbk1        0.052859      0.061536               0.077114
# eps8        0.012731      0.014419               0.016305
# ...              ...           ...                    ...
# pth1a       0.000010      0.000010               0.000010
# cacna2d4b   0.000020      0.000020               0.000020
# BX294110.1  0.000025      0.000025               0.000026
# sigirr      0.000010      0.000010               0.000010
# cyp11a2     0.000010      0.000010               0.000010
#
#             vst.variance.standardized  vst.variable
# dusp16                       0.827897             0
# crebl2                       0.801682             0
# gpr19                        0.842656             0
# tbk1                         0.797989             0
# eps8                         0.884331             0
# ...                               ...           ...
# pth1a                        0.989420             0
# cacna2d4b                    0.969200             0
# BX294110.1                   0.962246             0
# sigirr                       0.989420             0
# cyp11a2                      0.989420             0
#
# [23466 rows x 5 columns]

# %% [markdown]
# Here we rename genes to ENSEMBL ID for correct matching between single cell and spatial data.

# %%
adata_ref.var['SYMBOL'] = adata_ref.var_names

adata_ref.var
# Out:
#             vst.mean  vst.variance  vst.variance.expected  \
# dusp16      0.014383      0.015363               0.018556
# crebl2      0.031193      0.033800               0.042161
# gpr19       0.002250      0.002264               0.002687
# tbk1        0.052859      0.061536               0.077114
# eps8        0.012731      0.014419               0.016305
# ...              ...           ...                    ...
# pth1a       0.000010      0.000010               0.000010
# cacna2d4b   0.000020      0.000020               0.000020
# BX294110.1  0.000025      0.000025               0.000026
# sigirr      0.000010      0.000010               0.000010
# cyp11a2     0.000010      0.000010               0.000010
#
#             vst.variance.standardized  vst.variable      SYMBOL
# dusp16                       0.827897             0      dusp16
# crebl2                       0.801682             0      crebl2
# gpr19                        0.842656             0       gpr19
# tbk1                         0.797989             0        tbk1
# eps8                         0.884331             0        eps8
# ...                               ...           ...         ...
# pth1a                        0.989420             0       pth1a
# cacna2d4b                    0.969200             0   cacna2d4b
# BX294110.1                   0.962246             0  BX294110.1
# sigirr                       0.989420             0      sigirr
# cyp11a2                      0.989420             0     cyp11a2
#
# [23466 rows x 6 columns]

# %% [markdown]
# Before we estimate the reference cell type signature we recommend to perform very permissive genes selection. We prefer this to standard highly-variable-gene selection because our procedure keeps markers of rare genes while removing most of the uninformative genes.
#
# The default parameters cell_count_cutoff=5, cell_percentage_cutoff2=0.03, nonz_mean_cutoff=1.12 are a good starting point, however, you can increase the cut-off to exclude more genes. To preserve marker genes of rare cell types we recommend low cell_count_cutoff=5, however, cell_percentage_cutoff2 and nonz_mean_cutoff can be increased to select between 8k-16k genes.

# %%
from cell2location.utils.filtering import filter_genes
selected = filter_genes(adata_ref, cell_count_cutoff=5, cell_percentage_cutoff2=0.03, nonz_mean_cutoff=1.04)

# filter the object
adata_ref_filter = adata_ref[:, selected].copy()

# %%
adata_ref = adata_ref_filter
adata_ref
# Out:
# AnnData object with n_obs × n_vars = 73858 × 10485
#     obs: 'orig.ident', 'nCount_originalexp', 'nFeature_originalexp', 'time', 'morphine', 'AV', 'inhib', 'plot.ident2', 'nCount_RNA', 'nFeature_RNA'
#     var: 'vst.mean', 'vst.variance', 'vst.variance.expected', 'vst.variance.standardized', 'vst.variable', 'SYMBOL', 'n_cells', 'nonz_mean'

# %% [markdown]
# # Estimation of reference cell type signatures (NB regression)

# %%
inf_aver = cell2location.cluster_averages.cluster_averages.compute_cluster_averages(adata_ref, 'plot.ident2', use_raw=True, layer=None)

# %%
inf_aver
# Out:
#              B-cells  Bl.ves.EC (apnln)  Bl.ves.EC (lyve1)  \
# dusp16      0.005510           0.002372           0.004267
# crebl2      0.011019           0.014229           0.079659
# gpr19       0.000000           0.000791           0.002845
# tbk1        0.035813           0.009486           0.058321
# eps8        0.000000           0.000000           0.007112
# ...              ...                ...                ...
# pth1a       0.000000           0.000000           0.000000
# cacna2d4b   0.000000           0.000000           0.000000
# BX294110.1  0.000000           0.000000           0.000000
# sigirr      0.000000           0.000000           0.000000
# cyp11a2     0.000000           0.000000           0.000000
#
#             Bl.ves.EC (plvapb)  Cardiomyocytes (proliferating)  \
# dusp16                0.006772                        0.000000
# crebl2                0.077502                        0.038168
# gpr19                 0.002257                        0.003817
# tbk1                  0.055681                        0.003817
# eps8                  0.031603                        0.003817
# ...                        ...                             ...
# pth1a                 0.000000                        0.000000
# cacna2d4b             0.000000                        0.000000
# BX294110.1            0.000000                        0.000000
# sigirr                0.000000                        0.000000
# cyp11a2               0.000000                        0.000000
#
#             Cardiomyocytes (ttn.2) A  Cardiomyocytes (ttn.2) V  \
# dusp16                      0.006079                  0.008299
# crebl2                      0.017477                  0.037344
# gpr19                       0.005319                  0.016598
# tbk1                        0.030395                  0.037344
# eps8                        0.001520                  0.000000
# ...                              ...                       ...
# pth1a                       0.000000                  0.000000
# cacna2d4b                   0.000000                  0.000000
# BX294110.1                  0.000000                  0.000000
# sigirr                      0.000000                  0.000000
# cyp11a2                     0.000000                  0.000000
#
#             Cardiomyocytes A  Cardiomyocytes V  Dead cells  ...  Monocytes  \
# dusp16              0.000763          0.000936         0.0  ...   0.025253
# crebl2              0.012723          0.020592         0.0  ...   0.020202
# gpr19               0.001781          0.001053         0.0  ...   0.000000
# tbk1                0.007125          0.005616         0.0  ...   0.042929
# eps8                0.000000          0.001170         0.0  ...   0.000000
# ...                      ...               ...         ...  ...        ...
# pth1a               0.000000          0.000000         0.0  ...   0.000000
# cacna2d4b           0.000000          0.000000         0.0  ...   0.000000
# BX294110.1          0.000000          0.000000         0.0  ...   0.000000
# sigirr              0.000000          0.000000         0.0  ...   0.000000
# cyp11a2             0.000000          0.000000         0.0  ...   0.000000
#
#             Myelin cells  Neuronal cells  Neutrophils  Perivascular cells  \
# dusp16          0.000000        0.000000     0.006652            0.000000
# crebl2          0.045296        0.705882     0.028825            0.036885
# gpr19           0.000000        0.029412     0.000000            0.001366
# tbk1            0.052265        0.235294     0.044346            0.017760
# eps8            0.006969        0.058824     0.000000            0.016393
# ...                  ...             ...          ...                 ...
# pth1a           0.000000        0.000000     0.000000            0.000000
# cacna2d4b       0.000000        0.000000     0.000000            0.000000
# BX294110.1      0.000000        0.000000     0.000000            0.000000
# sigirr          0.000000        0.000000     0.000000            0.000000
# cyp11a2         0.000000        0.000000     0.000000            0.000000
#
#             Proliferating cells  Smooth muscle cells   T-cells  \
# dusp16                 0.003731             0.009260  0.002335
# crebl2                 0.063433             0.067870  0.010117
# gpr19                  0.000000             0.006564  0.000778
# tbk1                   0.041045             0.043723  0.021401
# eps8                   0.029851             0.004689  0.000000
# ...                         ...                  ...       ...
# pth1a                  0.000000             0.000000  0.000000
# cacna2d4b              0.000000             0.000000  0.000000
# BX294110.1             0.000000             0.000000  0.000000
# sigirr                 0.000000             0.000000  0.000000
# cyp11a2                0.000000             0.000000  0.000000
#
#             T-cells (il4/13)  T-cells (proliferating)
# dusp16              0.017857                 0.016129
# crebl2              0.000000                 0.032258
# gpr19               0.000000                 0.000000
# tbk1                0.035714                 0.016129
# eps8                0.000000                 0.000000
# ...                      ...                      ...
# pth1a               0.000000                 0.000000
# cacna2d4b           0.000000                 0.000000
# BX294110.1          0.000000                 0.000000
# sigirr              0.000000                 0.000000
# cyp11a2             0.000000                 0.000000
#
# [23466 rows x 45 columns]

# %%
# find shared genes and subset both anndata and reference signatures
intersect = np.intersect1d(adata_vis.var_names, inf_aver.index)
adata_vis = adata_vis[:, intersect].copy()
inf_aver = inf_aver.loc[intersect, :].copy()

# prepare anndata for cell2location model
cell2location.models.Cell2location.setup_anndata(adata=adata_vis, batch_key="orig.ident")

# %%
adata_vis
# Out:
# AnnData object with n_obs × n_vars = 318 × 22030
#     obs: 'orig.ident', 'nCount_Spatial', 'nFeature_Spatial', '_indices', '_scvi_batch', '_scvi_labels'
#     var: 'features', 'MT_gene'
#     uns: '_scvi_uuid', '_scvi_manager_uuid'
#     obsm: 'MT'

# %%
# create and train the model
mod = cell2location.models.Cell2location(
    adata_vis, cell_state_df=inf_aver,
    # the expected average cell abundance: tissue-dependent
    # hyper-prior which can be estimated from paired histology:
    N_cells_per_location=25,
    # hyperparameter controlling normalisation of
    # within-experiment variation in RNA detection:
    detection_alpha=20
)
mod.view_anndata_setup()
# Out:
# Anndata setup with scvi-tools version 0.16.2.
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# Setup via `Cell2location.setup_anndata` with arguments:
# {
# │   'layer': None,
# │   'batch_key': 'orig.ident',
# │   'labels_key': None,
# │   'categorical_covariate_keys': None,
# │   'continuous_covariate_keys': None
# }
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
#          Summary Statistics
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━┓
# ┃     Summary Stat Key     ┃ Value ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━┩
# │         n_cells          │  318  │
# │          n_vars          │ 22030 │
# │         n_batch          │   1   │
# │         n_labels         │   1   │
# │ n_extra_categorical_covs │   0   │
# │ n_extra_continuous_covs  │   0   │
# └──────────────────────────┴───────┘
#                Data Registry
# ┏━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Registry Key ┃    scvi-tools Location    ┃
# ┡━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━┩
# │      X       │          adata.X          │
# │    batch     │ adata.obs['_scvi_batch']  │
# │    labels    │ adata.obs['_scvi_labels'] │
# │    ind_x     │   adata.obs['_indices']   │
# └──────────────┴───────────────────────────┘
#                      batch State Registry
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━┓
# ┃     Source Location     ┃ Categories ┃ scvi-tools Encoding ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━┩
# │ adata.obs['orig.ident'] │     0      │          0          │
# └─────────────────────────┴────────────┴─────────────────────┘
#                      labels State Registry
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━┓
# ┃      Source Location      ┃ Categories ┃ scvi-tools Encoding ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━┩
# │ adata.obs['_scvi_labels'] │     0      │          0          │
# └───────────────────────────┴────────────┴─────────────────────┘

# %% [markdown]
# Training cell2location:

# %%
mod.train(max_epochs=15000,
          # train using full data (batch_size=None)
          batch_size=None,
          # use all data points in training because
          # we need to estimate cell abundance at all locations
          train_size=1,
          use_gpu=False)

# plot ELBO loss history during training, removing first 100 epochs from the plot
mod.plot_history(1000)
plt.legend(labels=['full data training']);
# Out:
# GPU available: False, used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# /Users/emparbaltasarperez/miniconda3/envs/cell2loc_env/lib/python3.9/site-packages/pytorch_lightning/trainer/configuration_validator.py:120: UserWarning: You passed in a `val_dataloader` but have no `validation_step`. Skipping val loop.
#   rank_zero_warn("You passed in a `val_dataloader` but have no `validation_step`. Skipping val loop.")
# /Users/emparbaltasarperez/miniconda3/envs/cell2loc_env/lib/python3.9/site-packages/pytorch_lightning/trainer/data_loading.py:432: UserWarning: The number of training samples (1) is smaller than the logging interval Trainer(log_every_n_steps=10). Set a lower value for log_every_n_steps if you want to see logs for the training epoch.
#   rank_zero_warn(
# Epoch 15000/15000: 100%|██████████████████████████████████████████████████████████████████████| 15000/15000 [4:08:04<00:00,  1.01it/s, v_num=1, elbo_train=1.23e+6]

# %%
mod
# Out:
# cell2location model with the following params:
# n_factors: 45
# n_batch: 1
# Training status: Trained

# %%
# In this section, we export the estimated cell abundance (summary of the posterior distribution).
adata_vis = mod.export_posterior(
    adata_vis, sample_kwargs={'num_samples': 1000, 'batch_size': mod.adata.n_obs, 'use_gpu': False}
)
# Out:
# Sampling local variables, batch:   0%|                                                                                                         | 0/1 [02:34<?, ?it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [29], in <cell line: 2>()
#       1 # In this section, we export the estimated cell abundance (summary of the posterior distribution).
# ----> 2 adata_vis = mod.export_posterior(
#       3     adata_vis, sample_kwargs={'num_samples': 1000, 'batch_size': mod.adata.n_obs, 'use_gpu': False}
#       4 )
#
# File ~/miniconda3/envs/cell2loc_env/lib/python3.9/site-packages/cell2location/models/_cell2location_model.py:338, in Cell2location.export_posterior(self, adata, sample_kwargs, export_slot, add_to_obsm)
#     334 sample_kwargs = sample_kwargs if isinstance(sample_kwargs, dict) else dict()
#     336 # generate samples from posterior distributions for all parameters
#     337 # and compute mean, 5%/95% quantiles and standard deviation
# --> 338 self.samples = self.sample_posterior(**sample_kwargs)
#     339 # TODO use add_to_obsm to determine which quantiles need to be computed,
#     340 # and if means and stds are not in the list - use quantile methods rather than sampling posterior
#     341
#     342 # export posterior distribution summary for all parameters and
#     343 # annotation (model, date, var, obs and cell type names) to anndata object
#     344 adata.uns[export_slot] = self._export2adata(self.samples)
#
# File ~/miniconda3/envs/cell2loc_env/lib/python3.9/site-packages/scvi/model/base/_pyromixin.py:483, in PyroSampleMixin.sample_posterior(self, num_samples, return_sites, use_gpu, batch_size, return_observed, return_samples, summary_fun)
#     436 """
#     437 Summarise posterior distribution.
#     438
#    (...)
#     480 to keep all model-specific variables in one place.
#     481 """
#     482 # sample using minibatches (if full data, data is moved to GPU only once anyway)
# --> 483 samples = self._posterior_samples_minibatch(
#     484     use_gpu=use_gpu,
#     485     batch_size=batch_size,
#     486     num_samples=num_samples,
#     487     return_sites=return_sites,
#     488     return_observed=return_observed,
#     489 )
#     491 param_names = list(samples.keys())
#     492 results = dict()
#
# File ~/miniconda3/envs/cell2loc_env/lib/python3.9/site-packages/scvi/model/base/_pyromixin.py:387, in PyroSampleMixin._posterior_samples_minibatch(self, use_gpu, batch_size, **sample_kwargs)
#     380     sample_kwargs_obs_plate[
#     381         "return_sites"
#     382     ] = self._get_obs_plate_return_sites(
#     383         sample_kwargs["return_sites"], list(obs_plate_sites.keys())
#     384     )
#     385     sample_kwargs_obs_plate["show_progress"] = False
# --> 387     samples = self._get_posterior_samples(
#     388         args, kwargs, **sample_kwargs_obs_plate
#     389     )
#     390 else:
#     391     samples_ = self._get_posterior_samples(
#     392         args, kwargs, **sample_kwargs_obs_plate
#     393     )
#
# File ~/miniconda3/envs/cell2loc_env/lib/python3.9/site-packages/scvi/model/base/_pyromixin.py:257, in PyroSampleMixin._get_posterior_samples(self, args, kwargs, num_samples, return_sites, return_observed, show_progress)
#     247 samples = {k: [v] for k, v in samples.items()}
#     249 for _ in track(
#     250     range(1, num_samples),
#     251     style="tqdm",
#    (...)
#     255
#     256     # generate new sample
# --> 257     samples_ = self._get_one_posterior_sample(
#     258         args, kwargs, return_sites=return_sites, return_observed=return_observed
#     259     )
#     261     # add new sample
#     262     samples = {k: samples[k] + [samples_[k]] for k in samples.keys()}
#
# File ~/miniconda3/envs/cell2loc_env/lib/python3.9/site-packages/torch/autograd/grad_mode.py:27, in _DecoratorContextManager.__call__.<locals>.decorate_context(*args, **kwargs)
#      24 @functools.wraps(func)
#      25 def decorate_context(*args, **kwargs):
#      26     with self.clone():
# ---> 27         return func(*args, **kwargs)
#
# File ~/miniconda3/envs/cell2loc_env/lib/python3.9/site-packages/scvi/model/base/_pyromixin.py:187, in PyroSampleMixin._get_one_posterior_sample(self, args, kwargs, return_sites, return_observed)
#     185 else:
#     186     guide_trace = poutine.trace(self.module.guide).get_trace(*args, **kwargs)
# --> 187     model_trace = poutine.trace(
#     188         poutine.replay(self.module.model, guide_trace)
#     189     ).get_trace(*args, **kwargs)
#     190     sample = {
#     191         name: site["value"]
#     192         for name, site in model_trace.nodes.items()
#    (...)
#     207         )
#     208     }
#     210 sample = {name: site.cpu().numpy() for name, site in sample.items()}
#
# File ~/miniconda3/envs/cell2loc_env/lib/python3.9/site-packages/pyro/poutine/trace_messenger.py:198, in TraceHandler.get_trace(self, *args, **kwargs)
#     190 def get_trace(self, *args, **kwargs):
#     191     """
#     192     :returns: data structure
#     193     :rtype: pyro.poutine.Trace
#    (...)
#     196     Calls this poutine and returns its trace instead of the function's return value.
#     197     """
# --> 198     self(*args, **kwargs)
#     199     return self.msngr.get_trace()
#
# File ~/miniconda3/envs/cell2loc_env/lib/python3.9/site-packages/pyro/poutine/trace_messenger.py:174, in TraceHandler.__call__(self, *args, **kwargs)
#     170 self.msngr.trace.add_node(
#     171     "_INPUT", name="_INPUT", type="args", args=args, kwargs=kwargs
#     172 )
#     173 try:
# --> 174     ret = self.fn(*args, **kwargs)
#     175 except (ValueError, RuntimeError) as e:
#     176     exc_type, exc_value, traceback = sys.exc_info()
#
# File ~/miniconda3/envs/cell2loc_env/lib/python3.9/site-packages/pyro/poutine/messenger.py:12, in _context_wrap(context, fn, *args, **kwargs)
#      10 def _context_wrap(context, fn, *args, **kwargs):
#      11     with context:
# ---> 12         return fn(*args, **kwargs)
#
# File ~/miniconda3/envs/cell2loc_env/lib/python3.9/site-packages/pyro/nn/module.py:427, in PyroModule.__call__(self, *args, **kwargs)
#     425 def __call__(self, *args, **kwargs):
#     426     with self._pyro_context:
# --> 427         return super().__call__(*args, **kwargs)
#
# File ~/miniconda3/envs/cell2loc_env/lib/python3.9/site-packages/torch/nn/modules/module.py:1110, in Module._call_impl(self, *input, **kwargs)
#    1106 # If we don't have any hooks, we want to skip the rest of the logic in
#    1107 # this function, and just call forward.
#    1108 if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1109         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1110     return forward_call(*input, **kwargs)
#    1111 # Do not call functions when jit is used
#    1112 full_backward_hooks, non_full_backward_hooks = [], []
#
# File ~/miniconda3/envs/cell2loc_env/lib/python3.9/site-packages/cell2location/models/_cell2location_module.py:463, in LocationModelLinearDependentWMultiExperimentLocationBackgroundNormLevelGeneAlphaPyroModel.forward(self, x_data, idx, batch_index)
#     460 # =====================Expected expression ======================= #
#     461 if not self.training_wo_observed:
#     462     # expected expression
# --> 463     mu = ((w_sf @ self.cell_state) * m_g + (obs2sample @ s_g_gene_add)) * detection_y_s
#     464     alpha = obs2sample @ (self.ones / alpha_g_inverse.pow(2))
#     465     # convert mean and overdispersion to total count and logits
#     466     # total_count, logits = _convert_mean_disp_to_counts_logits(
#     467     #    mu, alpha, eps=self.eps
#    (...)
#     470     # =====================DATA likelihood ======================= #
#     471     # Likelihood (sampling distribution) of data_target & add overdispersion via NegativeBinomial
#
# KeyboardInterrupt:

# %%
adata_vis
# Out:
# AnnData object with n_obs × n_vars = 454 × 22030
#     obs: 'orig.ident', 'nCount_Spatial', 'nFeature_Spatial', '_indices', '_scvi_batch', '_scvi_labels'
#     var: 'features', 'MT_gene'
#     uns: '_scvi_uuid', '_scvi_manager_uuid', 'mod'
#     obsm: 'MT', 'means_cell_abundance_w_sf', 'stds_cell_abundance_w_sf', 'q05_cell_abundance_w_sf', 'q95_cell_abundance_w_sf'

# %%
# Save model
mod.save(f"{run_name}", overwrite=True)

# mod = cell2location.models.Cell2location.load(f"{run_name}", adata_vis)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Input In [30], in <cell line: 2>()
#       1 # Save model
# ----> 2 mod.save(f"{run_name}", overwrite=True)
#
# File ~/miniconda3/envs/cell2loc_env/lib/python3.9/site-packages/scvi/model/base/_base_model.py:507, in BaseModelClass.save(self, dir_path, prefix, overwrite, save_anndata, **anndata_write_kwargs)
#     485 """
#     486 Save the state of the model.
#     487
#    (...)
#     504     Kwargs for :meth:`~anndata.AnnData.write`
#     505 """
#     506 if not os.path.exists(dir_path) or overwrite:
# --> 507     os.makedirs(dir_path, exist_ok=overwrite)
#     508 else:
#     509     raise ValueError(
#     510         "{} already exists. Please provide an unexisting directory for saving.".format(
#     511             dir_path
#     512         )
#     513     )
#
# File ~/miniconda3/envs/cell2loc_env/lib/python3.9/os.py:215, in makedirs(name, mode, exist_ok)
#     213 if head and tail and not path.exists(head):
#     214     try:
# --> 215         makedirs(head, exist_ok=exist_ok)
#     216     except FileExistsError:
#     217         # Defeats race condition when another thread created the path
#     218         pass
#
# File ~/miniconda3/envs/cell2loc_env/lib/python3.9/os.py:215, in makedirs(name, mode, exist_ok)
#     213 if head and tail and not path.exists(head):
#     214     try:
# --> 215         makedirs(head, exist_ok=exist_ok)
#     216     except FileExistsError:
#     217         # Defeats race condition when another thread created the path
#     218         pass
#
#     [... skipping similar frames: makedirs at line 215 (2 times)]
#
# File ~/miniconda3/envs/cell2loc_env/lib/python3.9/os.py:215, in makedirs(name, mode, exist_ok)
#     213 if head and tail and not path.exists(head):
#     214     try:
# --> 215         makedirs(head, exist_ok=exist_ok)
#     216     except FileExistsError:
#     217         # Defeats race condition when another thread created the path
#     218         pass
#
# File ~/miniconda3/envs/cell2loc_env/lib/python3.9/os.py:225, in makedirs(name, mode, exist_ok)
#     223         return
#     224 try:
# --> 225     mkdir(name, mode)
#     226 except OSError:
#     227     # Cannot rely on checking for EEXIST, since the operating system
#     228     # could give priority to other errors like EACCES or EROFS
#     229     if not exist_ok or not path.isdir(name):
#
# FileNotFoundError: [Errno 2] No such file or directory: '.'

# %%
adata_vis.var.index.names = ['gene']

# %%
adata_vis
# Out:
# AnnData object with n_obs × n_vars = 454 × 22030
#     obs: 'orig.ident', 'nCount_Spatial', 'nFeature_Spatial', '_indices', '_scvi_batch', '_scvi_labels'
#     var: 'features', 'MT_gene'
#     uns: '_scvi_uuid', '_scvi_manager_uuid', 'mod'
#     obsm: 'MT', 'means_cell_abundance_w_sf', 'stds_cell_abundance_w_sf', 'q05_cell_abundance_w_sf', 'q95_cell_abundance_w_sf'

# %%
# Save anndata object with results 
adata_file = "/Volumes/T7/SCD/projects/visium-pipeline-development/output/cell2location/zebrafish_heart/SCD-VI-i001/cell2location_map/sp.h5ad"
adata_vis.write(adata_file)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~/miniconda3/envs/cell2loc_env/lib/python3.9/site-packages/anndata/_io/utils.py:214, in report_write_key_on_error.<locals>.func_wrapper(elem, key, val, *args, **kwargs)
#     213 try:
# --> 214     return func(elem, key, val, *args, **kwargs)
#     215 except Exception as e:
#
# File ~/miniconda3/envs/cell2loc_env/lib/python3.9/site-packages/anndata/_io/specs/registry.py:175, in write_elem(f, k, elem, modifiers, *args, **kwargs)
#     174 else:
# --> 175     _REGISTRY.get_writer(dest_type, t, modifiers)(f, k, elem, *args, **kwargs)
#
# File ~/miniconda3/envs/cell2loc_env/lib/python3.9/site-packages/anndata/_io/specs/registry.py:24, in write_spec.<locals>.decorator.<locals>.wrapper(g, k, *args, **kwargs)
#      22 @wraps(func)
#      23 def wrapper(g, k, *args, **kwargs):
# ---> 24     result = func(g, k, *args, **kwargs)
#      25     g[k].attrs.setdefault("encoding-type", spec.encoding_type)
#
# File ~/miniconda3/envs/cell2loc_env/lib/python3.9/site-packages/anndata/_io/specs/methods.py:497, in write_dataframe(f, key, df, dataset_kwargs)
#     496     if reserved in df.columns:
# --> 497         raise ValueError(f"{reserved!r} is a reserved name for dataframe columns.")
#     498 group = f.create_group(key)
#
# ValueError: '_index' is a reserved name for dataframe columns.
#
# The above exception was the direct cause of the following exception:
#
# ValueError                                Traceback (most recent call last)
# Input In [101], in <cell line: 3>()
#       1 # Save anndata object with results
#       2 adata_file = "/Volumes/T7/SCD/projects/visium-pipeline-development/output/cell2location/zebrafish_heart/SCD-VI-i001/cell2location_map/sp.h5ad"
# ----> 3 adata_vis.write(adata_file)
#
# File ~/miniconda3/envs/cell2loc_env/lib/python3.9/site-packages/anndata/_core/anndata.py:1918, in AnnData.write_h5ad(self, filename, compression, compression_opts, force_dense, as_dense)
#    1915 if filename is None:
#    1916     filename = self.filename
# -> 1918 _write_h5ad(
#    1919     Path(filename),
#    1920     self,
#    1921     compression=compression,
#    1922     compression_opts=compression_opts,
#    1923     force_dense=force_dense,
#    1924     as_dense=as_dense,
#    1925 )
#    1927 if self.isbacked:
#    1928     self.file.filename = filename
#
# File ~/miniconda3/envs/cell2loc_env/lib/python3.9/site-packages/anndata/_io/h5ad.py:97, in write_h5ad(filepath, adata, force_dense, as_dense, dataset_kwargs, **kwargs)
#      93     write_elem(
#      94         f, "raw/varm", dict(adata.raw.varm), dataset_kwargs=dataset_kwargs
#      95     )
#      96 elif adata.raw is not None:
# ---> 97     write_elem(f, "raw", adata.raw, dataset_kwargs=dataset_kwargs)
#      98 write_elem(f, "obs", adata.obs, dataset_kwargs=dataset_kwargs)
#      99 write_elem(f, "var", adata.var, dataset_kwargs=dataset_kwargs)
#
# File ~/miniconda3/envs/cell2loc_env/lib/python3.9/site-packages/anndata/_io/utils.py:214, in report_write_key_on_error.<locals>.func_wrapper(elem, key, val, *args, **kwargs)
#     211 @wraps(func)
#     212 def func_wrapper(elem, key, val, *args, **kwargs):
#     213     try:
# --> 214         return func(elem, key, val, *args, **kwargs)
#     215     except Exception as e:
#     216         if "Above error raised while writing key" in format(e):
#
# File ~/miniconda3/envs/cell2loc_env/lib/python3.9/site-packages/anndata/_io/specs/registry.py:175, in write_elem(f, k, elem, modifiers, *args, **kwargs)
#     171     _REGISTRY.get_writer(dest_type, (t, elem.dtype.kind), modifiers)(
#     172         f, k, elem, *args, **kwargs
#     173     )
#     174 else:
# --> 175     _REGISTRY.get_writer(dest_type, t, modifiers)(f, k, elem, *args, **kwargs)
#
# File ~/miniconda3/envs/cell2loc_env/lib/python3.9/site-packages/anndata/_io/specs/registry.py:24, in write_spec.<locals>.decorator.<locals>.wrapper(g, k, *args, **kwargs)
#      22 @wraps(func)
#      23 def wrapper(g, k, *args, **kwargs):
# ---> 24     result = func(g, k, *args, **kwargs)
#      25     g[k].attrs.setdefault("encoding-type", spec.encoding_type)
#      26     g[k].attrs.setdefault("encoding-version", spec.encoding_version)
#
# File ~/miniconda3/envs/cell2loc_env/lib/python3.9/site-packages/anndata/_io/specs/methods.py:259, in write_raw(f, k, raw, dataset_kwargs)
#     257 g = f.create_group(k)
#     258 write_elem(g, "X", raw.X, dataset_kwargs=dataset_kwargs)
# --> 259 write_elem(g, "var", raw.var, dataset_kwargs=dataset_kwargs)
#     260 write_elem(g, "varm", dict(raw.varm), dataset_kwargs=dataset_kwargs)
#
# File ~/miniconda3/envs/cell2loc_env/lib/python3.9/site-packages/anndata/_io/utils.py:220, in report_write_key_on_error.<locals>.func_wrapper(elem, key, val, *args, **kwargs)
#     218 else:
#     219     parent = _get_parent(elem)
# --> 220     raise type(e)(
#     221         f"{e}\n\n"
#     222         f"Above error raised while writing key {key!r} of {type(elem)} "
#     223         f"to {parent}"
#     224     ) from e
#
# ValueError: '_index' is a reserved name for dataframe columns.
#
# Above error raised while writing key 'var' of <class 'h5py._hl.group.Group'> to /

# %%
# Reload the data
adata_file = "/Volumes/T7/SCD/projects/visium-pipeline-development/output/cell2location/zebrafish_heart/SCD-VI-i001/cell2location_map/sp.h5ad"
adata_vis_2 = sc.read_h5ad(adata_file)
mod_2 = cell2location.models.Cell2location.load("/Volumes/T7/SCD/projects/visium-pipeline-development/output/cell2location/zebrafish_heart/SCD-VI-i001/cell2location_map", adata_vis_2)
# Out:
# INFO     File /Volumes/T7/SCD/projects/visium-pipeline-development/output/cell2location/zebra
#          fish_heart/SCD-VI-i001/cell2location_map/model.pt already downloaded
# /Users/emparbaltasarperez/miniconda3/envs/cell2loc_env/lib/python3.9/site-packages/scvi/model/base/_utils.py:134: UserWarning: var_names for adata passed in does not match var_names of adata used to train the model. For valid results, the vars need to be the same and in the same order as the adata used to train the model.
#   warnings.warn(
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [74], in <cell line: 4>()
#       2 adata_file = "/Volumes/T7/SCD/projects/visium-pipeline-development/output/cell2location/zebrafish_heart/SCD-VI-i001/cell2location_map/sp.h5ad"
#       3 adata_vis_2 = sc.read_h5ad(adata_file)
# ----> 4 mod_2 = cell2location.models.Cell2location.load("/Volumes/T7/SCD/projects/visium-pipeline-development/output/cell2location/zebrafish_heart/SCD-VI-i001/cell2location_map", adata_vis_2)
#
# File ~/miniconda3/envs/cell2loc_env/lib/python3.9/site-packages/scvi/model/base/_base_model.py:611, in BaseModelClass.load(cls, dir_path, adata, use_gpu, prefix, backup_url)
#     603     raise ValueError(
#     604         "Saved model does not contain original setup inputs. "
#     605         "Cannot load the original setup."
#     606     )
#     608 # Calling ``setup_anndata`` method with the original arguments passed into
#     609 # the saved model. This enables simple backwards compatibility in the case of
#     610 # newly introduced fields or parameters.
# --> 611 cls.setup_anndata(adata, source_registry=registry, **registry[_SETUP_ARGS_KEY])
#     613 model = _initialize_model(cls, adata, attr_dict)
#     615 # some Pyro modules with AutoGuides may need one training step
#
# File ~/miniconda3/envs/cell2loc_env/lib/python3.9/site-packages/cell2location/models/_cell2location_model.py:160, in Cell2location.setup_anndata(cls, adata, layer, batch_key, labels_key, categorical_covariate_keys, continuous_covariate_keys, **kwargs)
#     151 anndata_fields = [
#     152     LayerField(REGISTRY_KEYS.X_KEY, layer, is_count_data=True),
#     153     CategoricalObsField(REGISTRY_KEYS.BATCH_KEY, batch_key),
#    (...)
#     157     NumericalObsField(REGISTRY_KEYS.INDICES_KEY, "_indices"),
#     158 ]
#     159 adata_manager = AnnDataManager(fields=anndata_fields, setup_method_args=setup_method_args)
# --> 160 adata_manager.register_fields(adata, **kwargs)
#     161 cls.register_manager(adata_manager)
#
# File ~/miniconda3/envs/cell2loc_env/lib/python3.9/site-packages/scvi/data/_manager.py:156, in AnnDataManager.register_fields(self, adata, source_registry, **transfer_kwargs)
#     151 if not field.is_empty:
#     152     # Transfer case: Source registry is used for validation and/or setup.
#     153     if source_registry is not None:
#     154         field_registry[
#     155             _constants._STATE_REGISTRY_KEY
# --> 156         ] = field.transfer_field(
#     157             source_registry[_constants._FIELD_REGISTRIES_KEY][
#     158                 field.registry_key
#     159             ][_constants._STATE_REGISTRY_KEY],
#     160             adata,
#     161             **transfer_kwargs,
#     162         )
#     163     else:
#     164         field_registry[
#     165             _constants._STATE_REGISTRY_KEY
#     166         ] = field.register_field(adata)
#
# File ~/miniconda3/envs/cell2loc_env/lib/python3.9/site-packages/scvi/data/fields/_obs_field.py:159, in CategoricalObsField.transfer_field(self, state_registry, adata_target, extend_categories, **kwargs)
#     156 if self.is_default:
#     157     self._setup_default_attr(adata_target)
# --> 159 self.validate_field(adata_target)
#     161 mapping = state_registry[self.CATEGORICAL_MAPPING_KEY].copy()
#     163 # extend mapping for new categories
#
# File ~/miniconda3/envs/cell2loc_env/lib/python3.9/site-packages/scvi/data/fields/_obs_field.py:130, in CategoricalObsField.validate_field(self, adata)
#     128 super().validate_field(adata)
#     129 if self._original_attr_key not in adata.obs:
# --> 130     raise KeyError(f"{self._original_attr_key} not found in adata.obs.")
#
# KeyError: 'orig.ident not found in adata.obs.'

# %%
adata_vis_2.obsm
# Out:
# AxisArrays with keys: MT

# %%
adata_vis
# Out:
# AnnData object with n_obs × n_vars = 454 × 22030
#     obs: 'orig.ident', 'nCount_Spatial', 'nFeature_Spatial', '_indices', '_scvi_batch', '_scvi_labels'
#     var: 'features', 'MT_gene'
#     uns: '_scvi_uuid', '_scvi_manager_uuid'
#     obsm: 'MT'

# %% [markdown]
# Assessing mapping quality. Examine reconstruction accuracy to assess if there are any issues with mapping. The plot should be roughly diagonal, strong deviations will signal problems that need to be investigated.

# %%
mod.plot_QC()

# %%
fig = mod.plot_spatial_QC_across_batches()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [32], in <cell line: 1>()
# ----> 1 fig = mod.plot_spatial_QC_across_batches()
#
# File ~/miniconda3/envs/cell2loc_env/lib/python3.9/site-packages/cell2location/models/_cell2location_model.py:408, in Cell2location.plot_spatial_QC_across_batches(self)
#     406 # plot, iterating across samples
#     407 for i, s in enumerate(samples):
# --> 408     sp_data_s = select_slide(adata, s, batch_key=batch_key)
#     409     scanpy.pl.spatial(
#     410         sp_data_s,
#     411         cmap="magma",
#    (...)
#     419         show=False,
#     420     )
#     421     axs[0, i].title.set_text(cell_type + "\n" + s)
#
# File ~/miniconda3/envs/cell2loc_env/lib/python3.9/site-packages/cell2location/utils/__init__.py:18, in select_slide(adata, s, batch_key)
#      10 r"""This function selects the data for one slide from the spatial anndata object.
#      11
#      12 :param adata: Anndata object with multiple spatial experiments
#      13 :param s: name of selected experiment
#      14 :param batch_key: column in adata.obs listing experiment name for each location
#      15 """
#      17 slide = adata[adata.obs[batch_key].isin([s]), :].copy()
# ---> 18 s_keys = list(slide.uns["spatial"].keys())
#      19 s_spatial = np.array(s_keys)[[s in k for k in s_keys]][0]
#      21 slide.uns["spatial"] = {s_spatial: slide.uns["spatial"][s_spatial]}
#
# File ~/miniconda3/envs/cell2loc_env/lib/python3.9/site-packages/anndata/compat/_overloaded_dict.py:100, in OverloadedDict.__getitem__(self, key)
#      98     return self.overloaded[key].get()
#      99 else:
# --> 100     return self.data[key]
#
# KeyError: 'spatial'

# %% [markdown]
# # Visualising cell abundance in spatial coordinates

# %%
adata_vis.obsm
# Out:
# AxisArrays with keys: MT, means_cell_abundance_w_sf, stds_cell_abundance_w_sf, q05_cell_abundance_w_sf, q95_cell_abundance_w_sf

# %%
adata_vis.obsm['means_cell_abundance_w_sf']
# Out:
#                     meanscell_abundance_w_sf_B-cells  \
# AAACGAGACGGTTGAT-1                          1.316686
# AAATTAACGGGTAGCT-1                          1.213097
# AAATTACCTATCGATG-1                          0.278998
# AACATATCAACTGGTG-1                          0.195581
# AACCGAGCTTGGTCAT-1                          2.588740
# ...                                              ...
# TTGGGACACTGCCCGC-1                          0.087417
# TTGGGCGGCGGTTGCC-1                          0.118166
# TTGTAAGGCCAGTTGG-1                          0.595630
# TTGTTCAGTGTGCTAC-1                          0.266551
# TTGTTGTGTGTCAAGA-1                          1.032958
#
#                     meanscell_abundance_w_sf_Bl.ves.EC (apnln)  \
# AAACGAGACGGTTGAT-1                                    0.253372
# AAATTAACGGGTAGCT-1                                    0.239459
# AAATTACCTATCGATG-1                                    0.333787
# AACATATCAACTGGTG-1                                    0.204003
# AACCGAGCTTGGTCAT-1                                    0.263631
# ...                                                        ...
# TTGGGACACTGCCCGC-1                                    0.111456
# TTGGGCGGCGGTTGCC-1                                    0.109486
# TTGTAAGGCCAGTTGG-1                                    0.197037
# TTGTTCAGTGTGCTAC-1                                    0.235937
# TTGTTGTGTGTCAAGA-1                                    0.176690
#
#                     meanscell_abundance_w_sf_Bl.ves.EC (lyve1)  \
# AAACGAGACGGTTGAT-1                                    0.136665
# AAATTAACGGGTAGCT-1                                    0.689552
# AAATTACCTATCGATG-1                                    0.035851
# AACATATCAACTGGTG-1                                    0.019058
# AACCGAGCTTGGTCAT-1                                    0.914693
# ...                                                        ...
# TTGGGACACTGCCCGC-1                                    0.029743
# TTGGGCGGCGGTTGCC-1                                    0.033099
# TTGTAAGGCCAGTTGG-1                                    0.215640
# TTGTTCAGTGTGCTAC-1                                    0.373208
# TTGTTGTGTGTCAAGA-1                                    0.205567
#
#                     meanscell_abundance_w_sf_Bl.ves.EC (plvapb)  \
# AAACGAGACGGTTGAT-1                                     0.126190
# AAATTAACGGGTAGCT-1                                     0.111882
# AAATTACCTATCGATG-1                                     0.109199
# AACATATCAACTGGTG-1                                     0.094030
# AACCGAGCTTGGTCAT-1                                     0.133487
# ...                                                         ...
# TTGGGACACTGCCCGC-1                                     0.025975
# TTGGGCGGCGGTTGCC-1                                     0.037278
# TTGTAAGGCCAGTTGG-1                                     0.111623
# TTGTTCAGTGTGCTAC-1                                     0.235056
# TTGTTGTGTGTCAAGA-1                                     0.064543
#
#                     meanscell_abundance_w_sf_Cardiomyocytes (proliferating)  \
# AAACGAGACGGTTGAT-1                                           0.104832
# AAATTAACGGGTAGCT-1                                           0.027425
# AAATTACCTATCGATG-1                                           0.363972
# AACATATCAACTGGTG-1                                           0.314308
# AACCGAGCTTGGTCAT-1                                           0.042375
# ...                                                               ...
# TTGGGACACTGCCCGC-1                                           0.029350
# TTGGGCGGCGGTTGCC-1                                           0.034392
# TTGTAAGGCCAGTTGG-1                                           0.065179
# TTGTTCAGTGTGCTAC-1                                           0.049082
# TTGTTGTGTGTCAAGA-1                                           0.055734
#
#                     meanscell_abundance_w_sf_Cardiomyocytes (ttn.2) A  \
# AAACGAGACGGTTGAT-1                                           0.067853
# AAATTAACGGGTAGCT-1                                           0.036351
# AAATTACCTATCGATG-1                                           1.414918
# AACATATCAACTGGTG-1                                           0.921844
# AACCGAGCTTGGTCAT-1                                           0.015061
# ...                                                               ...
# TTGGGACACTGCCCGC-1                                           0.053769
# TTGGGCGGCGGTTGCC-1                                           0.043800
# TTGTAAGGCCAGTTGG-1                                           0.096060
# TTGTTCAGTGTGCTAC-1                                           0.036061
# TTGTTGTGTGTCAAGA-1                                           0.098525
#
#                     meanscell_abundance_w_sf_Cardiomyocytes (ttn.2) V  \
# AAACGAGACGGTTGAT-1                                           0.105381
# AAATTAACGGGTAGCT-1                                           0.017935
# AAATTACCTATCGATG-1                                           2.613040
# AACATATCAACTGGTG-1                                           1.622639
# AACCGAGCTTGGTCAT-1                                           0.012349
# ...                                                               ...
# TTGGGACACTGCCCGC-1                                           0.067348
# TTGGGCGGCGGTTGCC-1                                           0.056042
# TTGTAAGGCCAGTTGG-1                                           0.319490
# TTGTTCAGTGTGCTAC-1                                           0.027177
# TTGTTGTGTGTCAAGA-1                                           0.054340
#
#                     meanscell_abundance_w_sf_Cardiomyocytes A  \
# AAACGAGACGGTTGAT-1                                   0.158353
# AAATTAACGGGTAGCT-1                                   0.049934
# AAATTACCTATCGATG-1                                   8.902561
# AACATATCAACTGGTG-1                                   9.182092
# AACCGAGCTTGGTCAT-1                                   0.060872
# ...                                                       ...
# TTGGGACACTGCCCGC-1                                   0.140330
# TTGGGCGGCGGTTGCC-1                                   0.143991
# TTGTAAGGCCAGTTGG-1                                   0.387959
# TTGTTCAGTGTGCTAC-1                                   0.073266
# TTGTTGTGTGTCAAGA-1                                   0.123012
#
#                     meanscell_abundance_w_sf_Cardiomyocytes V  \
# AAACGAGACGGTTGAT-1                                   0.153234
# AAATTAACGGGTAGCT-1                                   0.034139
# AAATTACCTATCGATG-1                                  14.654849
# AACATATCAACTGGTG-1                                  15.361525
# AACCGAGCTTGGTCAT-1                                   0.043788
# ...                                                       ...
# TTGGGACACTGCCCGC-1                                   0.196040
# TTGGGCGGCGGTTGCC-1                                   0.186793
# TTGTAAGGCCAGTTGG-1                                   0.420749
# TTGTTCAGTGTGCTAC-1                                   0.061652
# TTGTTGTGTGTCAAGA-1                                   0.126336
#
#                     meanscell_abundance_w_sf_Dead cells  ...  \
# AAACGAGACGGTTGAT-1                             0.198710  ...
# AAATTAACGGGTAGCT-1                             0.134245  ...
# AAATTACCTATCGATG-1                             0.256059  ...
# AACATATCAACTGGTG-1                             0.138984  ...
# AACCGAGCTTGGTCAT-1                             0.277456  ...
# ...                                                 ...  ...
# TTGGGACACTGCCCGC-1                             0.044467  ...
# TTGGGCGGCGGTTGCC-1                             0.057149  ...
# TTGTAAGGCCAGTTGG-1                             0.098608  ...
# TTGTTCAGTGTGCTAC-1                             0.087483  ...
# TTGTTGTGTGTCAAGA-1                             0.237069  ...
#
#                     meanscell_abundance_w_sf_Monocytes  \
# AAACGAGACGGTTGAT-1                            0.406890
# AAATTAACGGGTAGCT-1                            0.481162
# AAATTACCTATCGATG-1                            0.173699
# AACATATCAACTGGTG-1                            0.272265
# AACCGAGCTTGGTCAT-1                            0.215967
# ...                                                ...
# TTGGGACACTGCCCGC-1                            0.040518
# TTGGGCGGCGGTTGCC-1                            0.051884
# TTGTAAGGCCAGTTGG-1                            0.266477
# TTGTTCAGTGTGCTAC-1                            0.180609
# TTGTTGTGTGTCAAGA-1                            0.427367
#
#                     meanscell_abundance_w_sf_Myelin cells  \
# AAACGAGACGGTTGAT-1                               0.404846
# AAATTAACGGGTAGCT-1                               0.757634
# AAATTACCTATCGATG-1                               0.068987
# AACATATCAACTGGTG-1                               0.050024
# AACCGAGCTTGGTCAT-1                               0.365595
# ...                                                   ...
# TTGGGACACTGCCCGC-1                               0.042869
# TTGGGCGGCGGTTGCC-1                               0.053359
# TTGTAAGGCCAGTTGG-1                               0.333451
# TTGTTCAGTGTGCTAC-1                               0.144218
# TTGTTGTGTGTCAAGA-1                               0.280892
#
#                     meanscell_abundance_w_sf_Neuronal cells  \
# AAACGAGACGGTTGAT-1                                 0.424212
# AAATTAACGGGTAGCT-1                                 0.472384
# AAATTACCTATCGATG-1                                 0.014092
# AACATATCAACTGGTG-1                                 0.019574
# AACCGAGCTTGGTCAT-1                                 0.514067
# ...                                                     ...
# TTGGGACACTGCCCGC-1                                 0.018473
# TTGGGCGGCGGTTGCC-1                                 0.068457
# TTGTAAGGCCAGTTGG-1                                 0.213142
# TTGTTCAGTGTGCTAC-1                                 0.090204
# TTGTTGTGTGTCAAGA-1                                 0.166257
#
#                     meanscell_abundance_w_sf_Neutrophils  \
# AAACGAGACGGTTGAT-1                              1.713082
# AAATTAACGGGTAGCT-1                              1.222476
# AAATTACCTATCGATG-1                              0.618804
# AACATATCAACTGGTG-1                              0.414287
# AACCGAGCTTGGTCAT-1                              2.685443
# ...                                                  ...
# TTGGGACACTGCCCGC-1                              0.125016
# TTGGGCGGCGGTTGCC-1                              0.153241
# TTGTAAGGCCAGTTGG-1                              1.023589
# TTGTTCAGTGTGCTAC-1                              0.954446
# TTGTTGTGTGTCAAGA-1                              0.710574
#
#                     meanscell_abundance_w_sf_Perivascular cells  \
# AAACGAGACGGTTGAT-1                                     1.095742
# AAATTAACGGGTAGCT-1                                     1.235856
# AAATTACCTATCGATG-1                                     0.063775
# AACATATCAACTGGTG-1                                     0.050136
# AACCGAGCTTGGTCAT-1                                     0.808708
# ...                                                         ...
# TTGGGACACTGCCCGC-1                                     0.079499
# TTGGGCGGCGGTTGCC-1                                     0.072321
# TTGTAAGGCCAGTTGG-1                                     0.531384
# TTGTTCAGTGTGCTAC-1                                     0.339829
# TTGTTGTGTGTCAAGA-1                                     0.463195
#
#                     meanscell_abundance_w_sf_Proliferating cells  \
# AAACGAGACGGTTGAT-1                                      0.170437
# AAATTAACGGGTAGCT-1                                      0.215613
# AAATTACCTATCGATG-1                                      0.080565
# AACATATCAACTGGTG-1                                      0.054274
# AACCGAGCTTGGTCAT-1                                      0.290579
# ...                                                          ...
# TTGGGACACTGCCCGC-1                                      0.020704
# TTGGGCGGCGGTTGCC-1                                      0.024694
# TTGTAAGGCCAGTTGG-1                                      0.119823
# TTGTTCAGTGTGCTAC-1                                      0.073663
# TTGTTGTGTGTCAAGA-1                                      0.103989
#
#                     meanscell_abundance_w_sf_Smooth muscle cells  \
# AAACGAGACGGTTGAT-1                                      0.078803
# AAATTAACGGGTAGCT-1                                      0.110209
# AAATTACCTATCGATG-1                                      0.135722
# AACATATCAACTGGTG-1                                      0.092215
# AACCGAGCTTGGTCAT-1                                      0.066445
# ...                                                          ...
# TTGGGACACTGCCCGC-1                                      0.030911
# TTGGGCGGCGGTTGCC-1                                      0.042481
# TTGTAAGGCCAGTTGG-1                                      0.100022
# TTGTTCAGTGTGCTAC-1                                      0.145528
# TTGTTGTGTGTCAAGA-1                                      0.071233
#
#                     meanscell_abundance_w_sf_T-cells  \
# AAACGAGACGGTTGAT-1                          0.541544
# AAATTAACGGGTAGCT-1                          0.624335
# AAATTACCTATCGATG-1                          0.201943
# AACATATCAACTGGTG-1                          0.100616
# AACCGAGCTTGGTCAT-1                          0.350785
# ...                                              ...
# TTGGGACACTGCCCGC-1                          0.056487
# TTGGGCGGCGGTTGCC-1                          0.077697
# TTGTAAGGCCAGTTGG-1                          0.338534
# TTGTTCAGTGTGCTAC-1                          0.224828
# TTGTTGTGTGTCAAGA-1                          0.390674
#
#                     meanscell_abundance_w_sf_T-cells (il4/13)  \
# AAACGAGACGGTTGAT-1                                   0.205046
# AAATTAACGGGTAGCT-1                                   0.204842
# AAATTACCTATCGATG-1                                   1.255023
# AACATATCAACTGGTG-1                                   1.304365
# AACCGAGCTTGGTCAT-1                                   0.239745
# ...                                                       ...
# TTGGGACACTGCCCGC-1                                   0.054853
# TTGGGCGGCGGTTGCC-1                                   0.061497
# TTGTAAGGCCAGTTGG-1                                   0.179757
# TTGTTCAGTGTGCTAC-1                                   0.152105
# TTGTTGTGTGTCAAGA-1                                   0.168301
#
#                     meanscell_abundance_w_sf_T-cells (proliferating)
# AAACGAGACGGTTGAT-1                                          1.024000
# AAATTAACGGGTAGCT-1                                          1.651417
# AAATTACCTATCGATG-1                                          0.062669
# AACATATCAACTGGTG-1                                          0.013479
# AACCGAGCTTGGTCAT-1                                          0.405315
# ...                                                              ...
# TTGGGACACTGCCCGC-1                                          0.037262
# TTGGGCGGCGGTTGCC-1                                          0.042614
# TTGTAAGGCCAGTTGG-1                                          0.571908
# TTGTTCAGTGTGCTAC-1                                          0.497413
# TTGTTGTGTGTCAAGA-1                                          0.673544
#
# [454 rows x 45 columns]

# %%
adata_vis.obsm['q05_cell_abundance_w_sf']
# Out:
#                     q05cell_abundance_w_sf_B-cells  \
# AAACGAGACGGTTGAT-1                        0.846659
# AAATTAACGGGTAGCT-1                        0.741803
# AAATTACCTATCGATG-1                        0.112542
# AACATATCAACTGGTG-1                        0.063902
# AACCGAGCTTGGTCAT-1                        1.964275
# ...                                            ...
# TTGGGACACTGCCCGC-1                        0.009752
# TTGGGCGGCGGTTGCC-1                        0.014702
# TTGTAAGGCCAGTTGG-1                        0.291097
# TTGTTCAGTGTGCTAC-1                        0.086362
# TTGTTGTGTGTCAAGA-1                        0.573022
#
#                     q05cell_abundance_w_sf_Bl.ves.EC (apnln)  \
# AAACGAGACGGTTGAT-1                                  0.048881
# AAATTAACGGGTAGCT-1                                  0.040911
# AAATTACCTATCGATG-1                                  0.062211
# AACATATCAACTGGTG-1                                  0.028775
# AACCGAGCTTGGTCAT-1                                  0.054898
# ...                                                      ...
# TTGGGACACTGCCCGC-1                                  0.002351
# TTGGGCGGCGGTTGCC-1                                  0.003249
# TTGTAAGGCCAGTTGG-1                                  0.021156
# TTGTTCAGTGTGCTAC-1                                  0.028494
# TTGTTGTGTGTCAAGA-1                                  0.020812
#
#                     q05cell_abundance_w_sf_Bl.ves.EC (lyve1)  \
# AAACGAGACGGTTGAT-1                                  0.033938
# AAATTAACGGGTAGCT-1                                  0.387676
# AAATTACCTATCGATG-1                                  0.002399
# AACATATCAACTGGTG-1                                  0.000889
# AACCGAGCTTGGTCAT-1                                  0.575525
# ...                                                      ...
# TTGGGACACTGCCCGC-1                                  0.000782
# TTGGGCGGCGGTTGCC-1                                  0.000700
# TTGTAAGGCCAGTTGG-1                                  0.055587
# TTGTTCAGTGTGCTAC-1                                  0.120875
# TTGTTGTGTGTCAAGA-1                                  0.056090
#
#                     q05cell_abundance_w_sf_Bl.ves.EC (plvapb)  \
# AAACGAGACGGTTGAT-1                                   0.038905
# AAATTAACGGGTAGCT-1                                   0.025676
# AAATTACCTATCGATG-1                                   0.025493
# AACATATCAACTGGTG-1                                   0.025516
# AACCGAGCTTGGTCAT-1                                   0.035143
# ...                                                       ...
# TTGGGACACTGCCCGC-1                                   0.000931
# TTGGGCGGCGGTTGCC-1                                   0.001546
# TTGTAAGGCCAGTTGG-1                                   0.029289
# TTGTTCAGTGTGCTAC-1                                   0.073159
# TTGTTGTGTGTCAAGA-1                                   0.007982
#
#                     q05cell_abundance_w_sf_Cardiomyocytes (proliferating)  \
# AAACGAGACGGTTGAT-1                                           0.010435
# AAATTAACGGGTAGCT-1                                           0.001662
# AAATTACCTATCGATG-1                                           0.116957
# AACATATCAACTGGTG-1                                           0.116529
# AACCGAGCTTGGTCAT-1                                           0.004223
# ...                                                               ...
# TTGGGACACTGCCCGC-1                                           0.000346
# TTGGGCGGCGGTTGCC-1                                           0.000365
# TTGTAAGGCCAGTTGG-1                                           0.003859
# TTGTTCAGTGTGCTAC-1                                           0.002223
# TTGTTGTGTGTCAAGA-1                                           0.002306
#
#                     q05cell_abundance_w_sf_Cardiomyocytes (ttn.2) A  \
# AAACGAGACGGTTGAT-1                                         0.007414
# AAATTAACGGGTAGCT-1                                         0.002737
# AAATTACCTATCGATG-1                                         1.004954
# AACATATCAACTGGTG-1                                         0.616511
# AACCGAGCTTGGTCAT-1                                         0.000981
# ...                                                             ...
# TTGGGACACTGCCCGC-1                                         0.001116
# TTGGGCGGCGGTTGCC-1                                         0.001019
# TTGTAAGGCCAGTTGG-1                                         0.017697
# TTGTTCAGTGTGCTAC-1                                         0.002172
# TTGTTGTGTGTCAAGA-1                                         0.013942
#
#                     q05cell_abundance_w_sf_Cardiomyocytes (ttn.2) V  \
# AAACGAGACGGTTGAT-1                                         0.022383
# AAATTAACGGGTAGCT-1                                         0.000689
# AAATTACCTATCGATG-1                                         2.212950
# AACATATCAACTGGTG-1                                         1.307515
# AACCGAGCTTGGTCAT-1                                         0.000537
# ...                                                             ...
# TTGGGACACTGCCCGC-1                                         0.004867
# TTGGGCGGCGGTTGCC-1                                         0.003220
# TTGTAAGGCCAGTTGG-1                                         0.173273
# TTGTTCAGTGTGCTAC-1                                         0.001231
# TTGTTGTGTGTCAAGA-1                                         0.003593
#
#                     q05cell_abundance_w_sf_Cardiomyocytes A  \
# AAACGAGACGGTTGAT-1                                 0.013318
# AAATTAACGGGTAGCT-1                                 0.002830
# AAATTACCTATCGATG-1                                 7.478098
# AACATATCAACTGGTG-1                                 7.816612
# AACCGAGCTTGGTCAT-1                                 0.003421
# ...                                                     ...
# TTGGGACACTGCCCGC-1                                 0.016439
# TTGGGCGGCGGTTGCC-1                                 0.017025
# TTGTAAGGCCAGTTGG-1                                 0.078411
# TTGTTCAGTGTGCTAC-1                                 0.003998
# TTGTTGTGTGTCAAGA-1                                 0.011768
#
#                     q05cell_abundance_w_sf_Cardiomyocytes V  \
# AAACGAGACGGTTGAT-1                                 0.014788
# AAATTAACGGGTAGCT-1                                 0.001230
# AAATTACCTATCGATG-1                                13.319016
# AACATATCAACTGGTG-1                                14.233885
# AACCGAGCTTGGTCAT-1                                 0.002129
# ...                                                     ...
# TTGGGACACTGCCCGC-1                                 0.035607
# TTGGGCGGCGGTTGCC-1                                 0.029536
# TTGTAAGGCCAGTTGG-1                                 0.128990
# TTGTTCAGTGTGCTAC-1                                 0.003582
# TTGTTGTGTGTCAAGA-1                                 0.011257
#
#                     q05cell_abundance_w_sf_Dead cells  ...  \
# AAACGAGACGGTTGAT-1                           0.061111  ...
# AAATTAACGGGTAGCT-1                           0.025949  ...
# AAATTACCTATCGATG-1                           0.072882  ...
# AACATATCAACTGGTG-1                           0.026311  ...
# AACCGAGCTTGGTCAT-1                           0.112010  ...
# ...                                               ...  ...
# TTGGGACACTGCCCGC-1                           0.001654  ...
# TTGGGCGGCGGTTGCC-1                           0.002064  ...
# TTGTAAGGCCAGTTGG-1                           0.025480  ...
# TTGTTCAGTGTGCTAC-1                           0.012827  ...
# TTGTTGTGTGTCAAGA-1                           0.063669  ...
#
#                     q05cell_abundance_w_sf_Monocytes  \
# AAACGAGACGGTTGAT-1                          0.125436
# AAATTAACGGGTAGCT-1                          0.157196
# AAATTACCTATCGATG-1                          0.037567
# AACATATCAACTGGTG-1                          0.097736
# AACCGAGCTTGGTCAT-1                          0.066804
# ...                                              ...
# TTGGGACACTGCCCGC-1                          0.001902
# TTGGGCGGCGGTTGCC-1                          0.002886
# TTGTAAGGCCAGTTGG-1                          0.060780
# TTGTTCAGTGTGCTAC-1                          0.032949
# TTGTTGTGTGTCAAGA-1                          0.114125
#
#                     q05cell_abundance_w_sf_Myelin cells  \
# AAACGAGACGGTTGAT-1                             0.147634
# AAATTAACGGGTAGCT-1                             0.373058
# AAATTACCTATCGATG-1                             0.004235
# AACATATCAACTGGTG-1                             0.003056
# AACCGAGCTTGGTCAT-1                             0.129347
# ...                                                 ...
# TTGGGACACTGCCCGC-1                             0.001077
# TTGGGCGGCGGTTGCC-1                             0.001415
# TTGTAAGGCCAGTTGG-1                             0.100080
# TTGTTCAGTGTGCTAC-1                             0.018357
# TTGTTGTGTGTCAAGA-1                             0.062522
#
#                     q05cell_abundance_w_sf_Neuronal cells  \
# AAACGAGACGGTTGAT-1                               0.307722
# AAATTAACGGGTAGCT-1                               0.346295
# AAATTACCTATCGATG-1                               0.000621
# AACATATCAACTGGTG-1                               0.001757
# AACCGAGCTTGGTCAT-1                               0.387792
# ...                                                   ...
# TTGGGACACTGCCCGC-1                               0.000618
# TTGGGCGGCGGTTGCC-1                               0.005754
# TTGTAAGGCCAGTTGG-1                               0.126544
# TTGTTCAGTGTGCTAC-1                               0.020444
# TTGTTGTGTGTCAAGA-1                               0.065040
#
#                     q05cell_abundance_w_sf_Neutrophils  \
# AAACGAGACGGTTGAT-1                            1.185139
# AAATTAACGGGTAGCT-1                            0.794534
# AAATTACCTATCGATG-1                            0.380898
# AACATATCAACTGGTG-1                            0.242968
# AACCGAGCTTGGTCAT-1                            2.030107
# ...                                                ...
# TTGGGACACTGCCCGC-1                            0.022083
# TTGGGCGGCGGTTGCC-1                            0.031252
# TTGTAAGGCCAGTTGG-1                            0.622493
# TTGTTCAGTGTGCTAC-1                            0.548176
# TTGTTGTGTGTCAAGA-1                            0.347957
#
#                     q05cell_abundance_w_sf_Perivascular cells  \
# AAACGAGACGGTTGAT-1                                   0.609726
# AAATTAACGGGTAGCT-1                                   0.668216
# AAATTACCTATCGATG-1                                   0.004971
# AACATATCAACTGGTG-1                                   0.002402
# AACCGAGCTTGGTCAT-1                                   0.403529
# ...                                                       ...
# TTGGGACACTGCCCGC-1                                   0.002774
# TTGGGCGGCGGTTGCC-1                                   0.003010
# TTGTAAGGCCAGTTGG-1                                   0.212663
# TTGTTCAGTGTGCTAC-1                                   0.066837
# TTGTTGTGTGTCAAGA-1                                   0.155809
#
#                     q05cell_abundance_w_sf_Proliferating cells  \
# AAACGAGACGGTTGAT-1                                    0.056435
# AAATTAACGGGTAGCT-1                                    0.056197
# AAATTACCTATCGATG-1                                    0.007286
# AACATATCAACTGGTG-1                                    0.002486
# AACCGAGCTTGGTCAT-1                                    0.111455
# ...                                                        ...
# TTGGGACACTGCCCGC-1                                    0.000307
# TTGGGCGGCGGTTGCC-1                                    0.000432
# TTGTAAGGCCAGTTGG-1                                    0.023260
# TTGTTCAGTGTGCTAC-1                                    0.008766
# TTGTTGTGTGTCAAGA-1                                    0.014395
#
#                     q05cell_abundance_w_sf_Smooth muscle cells  \
# AAACGAGACGGTTGAT-1                                    0.009923
# AAATTAACGGGTAGCT-1                                    0.013569
# AAATTACCTATCGATG-1                                    0.023275
# AACATATCAACTGGTG-1                                    0.012921
# AACCGAGCTTGGTCAT-1                                    0.008892
# ...                                                        ...
# TTGGGACACTGCCCGC-1                                    0.000478
# TTGGGCGGCGGTTGCC-1                                    0.000801
# TTGTAAGGCCAGTTGG-1                                    0.009610
# TTGTTCAGTGTGCTAC-1                                    0.019421
# TTGTTGTGTGTCAAGA-1                                    0.005013
#
#                     q05cell_abundance_w_sf_T-cells  \
# AAACGAGACGGTTGAT-1                        0.161628
# AAATTAACGGGTAGCT-1                        0.164431
# AAATTACCTATCGATG-1                        0.024405
# AACATATCAACTGGTG-1                        0.010035
# AACCGAGCTTGGTCAT-1                        0.097252
# ...                                            ...
# TTGGGACACTGCCCGC-1                        0.002239
# TTGGGCGGCGGTTGCC-1                        0.003499
# TTGTAAGGCCAGTTGG-1                        0.076354
# TTGTTCAGTGTGCTAC-1                        0.031482
# TTGTTGTGTGTCAAGA-1                        0.073456
#
#                     q05cell_abundance_w_sf_T-cells (il4/13)  \
# AAACGAGACGGTTGAT-1                                 0.032634
# AAATTAACGGGTAGCT-1                                 0.032328
# AAATTACCTATCGATG-1                                 0.707113
# AACATATCAACTGGTG-1                                 0.806972
# AACCGAGCTTGGTCAT-1                                 0.044148
# ...                                                     ...
# TTGGGACACTGCCCGC-1                                 0.001915
# TTGGGCGGCGGTTGCC-1                                 0.002505
# TTGTAAGGCCAGTTGG-1                                 0.024729
# TTGTTCAGTGTGCTAC-1                                 0.014806
# TTGTTGTGTGTCAAGA-1                                 0.019873
#
#                     q05cell_abundance_w_sf_T-cells (proliferating)
# AAACGAGACGGTTGAT-1                                        0.738978
# AAATTAACGGGTAGCT-1                                        1.294362
# AAATTACCTATCGATG-1                                        0.006430
# AACATATCAACTGGTG-1                                        0.000476
# AACCGAGCTTGGTCAT-1                                        0.212687
# ...                                                            ...
# TTGGGACACTGCCCGC-1                                        0.001362
# TTGGGCGGCGGTTGCC-1                                        0.002211
# TTGTAAGGCCAGTTGG-1                                        0.310131
# TTGTTCAGTGTGCTAC-1                                        0.227014
# TTGTTGTGTGTCAAGA-1                                        0.352955
#
# [454 rows x 45 columns]

# %%
# add 5% quantile, representing confident cell abundance, 'at least this amount is present',
# to adata.obs with nice names for plotting
adata_vis.obs[adata_vis.uns['mod']['factor_names']] = adata_vis.obsm['q05_cell_abundance_w_sf']

# %%
# select one slide
from cell2location.utils import select_slide
slide = select_slide(adata_vis, 'V1_Mouse_Brain_Sagittal_Anterior')

# plot in spatial coordinates
with mpl.rc_context({'axes.facecolor':  'black',
                     'figure.figsize': [4.5, 5]}):

    sc.pl.spatial(slide, cmap='magma',
                  # show first 8 cell types
                  color=adata_vis.uns['mod']['factor_names'],
                  ncols=4, size=1.3,
                  img_key='hires',
                  # limit color scale at 99.2% quantile of cell abundance
                  vmin=0, vmax='p99.2'
                 )
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/miniconda3/envs/cell2loc_env/lib/python3.9/site-packages/pandas/core/indexes/base.py:3621, in Index.get_loc(self, key, method, tolerance)
#    3620 try:
# -> 3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
#
# File pandas/_libs/index.pyx:136, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:163, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:5198, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:5206, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'sample'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Input In [136], in <cell line: 7>()
#       5 # select one slide
#       6 from cell2location.utils import select_slide
# ----> 7 slide = select_slide(adata_vis, 0)
#       9 # plot in spatial coordinates
#      10 with mpl.rc_context({'axes.facecolor':  'black',
#      11                      'figure.figsize': [4.5, 5]}):
#
# File ~/miniconda3/envs/cell2loc_env/lib/python3.9/site-packages/cell2location/utils/__init__.py:17, in select_slide(adata, s, batch_key)
#       9 def select_slide(adata, s, batch_key="sample"):
#      10     r"""This function selects the data for one slide from the spatial anndata object.
#      11
#      12     :param adata: Anndata object with multiple spatial experiments
#      13     :param s: name of selected experiment
#      14     :param batch_key: column in adata.obs listing experiment name for each location
#      15     """
# ---> 17     slide = adata[adata.obs[batch_key].isin([s]), :].copy()
#      18     s_keys = list(slide.uns["spatial"].keys())
#      19     s_spatial = np.array(s_keys)[[s in k for k in s_keys]][0]
#
# File ~/miniconda3/envs/cell2loc_env/lib/python3.9/site-packages/pandas/core/frame.py:3505, in DataFrame.__getitem__(self, key)
#    3503 if self.columns.nlevels > 1:
#    3504     return self._getitem_multilevel(key)
# -> 3505 indexer = self.columns.get_loc(key)
#    3506 if is_integer(indexer):
#    3507     indexer = [indexer]
#
# File ~/miniconda3/envs/cell2loc_env/lib/python3.9/site-packages/pandas/core/indexes/base.py:3623, in Index.get_loc(self, key, method, tolerance)
#    3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
# -> 3623     raise KeyError(key) from err
#    3624 except TypeError:
#    3625     # If we have a listlike key, _check_indexing_error will raise
#    3626     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3627     #  the TypeError.
#    3628     self._check_indexing_error(key)
#
# KeyError: 'sample'

# %%
adata_vis.obs[adata_vis.uns['mod']['factor_names']]
# Out:
#                      B-cells  Bl.ves.EC (apnln)  Bl.ves.EC (lyve1)  \
# AAACAAGTATCTCCCA-1  0.026951           0.296695           0.110696
# AAATCTAGCCCTGCTA-1  0.051467           0.021885           0.007245
# AACACACGCTCGCCGC-1  0.013729           0.390010           0.488153
# AACCCGAGCAGAATCG-1  0.101771           0.069072           0.036833
# AACGCTGTTGCTGAAA-1  0.023475           0.265445           0.023039
# ...                      ...                ...                ...
# TTCCATCGACAGCGTG-1  0.047352           0.078636           0.018772
# TTCTTATCCGCTGGGT-1  0.038491           0.377010           0.075455
# TTGGACCATCTGGCAA-1  0.027529           0.016427           0.005526
# TTGGCTCAATATGTGT-1  0.021664           0.053761           0.020896
# TTGGGACGTAAGAGTT-1  0.002445           0.006799           0.001114
#
#                     Bl.ves.EC (plvapb)  Cardiomyocytes (proliferating)  \
# AAACAAGTATCTCCCA-1            0.026757                        0.701667
# AAATCTAGCCCTGCTA-1            0.076757                        0.804216
# AACACACGCTCGCCGC-1            0.090502                        0.175964
# AACCCGAGCAGAATCG-1            0.281715                        1.079400
# AACGCTGTTGCTGAAA-1            0.044025                        2.535028
# ...                                ...                             ...
# TTCCATCGACAGCGTG-1            0.044372                        1.024823
# TTCTTATCCGCTGGGT-1            1.139792                        0.712695
# TTGGACCATCTGGCAA-1            0.011626                        0.461808
# TTGGCTCAATATGTGT-1            0.011175                        0.566642
# TTGGGACGTAAGAGTT-1            0.001436                        0.056524
#
#                     Cardiomyocytes (ttn.2) A  Cardiomyocytes (ttn.2) V  \
# AAACAAGTATCTCCCA-1                  2.999252                  6.454447
# AAATCTAGCCCTGCTA-1                  2.799509                  1.745676
# AACACACGCTCGCCGC-1                  0.685351                  2.423648
# AACCCGAGCAGAATCG-1                  3.657352                  5.235313
# AACGCTGTTGCTGAAA-1                  2.159650                 10.166799
# ...                                      ...                       ...
# TTCCATCGACAGCGTG-1                  2.997654                  2.256883
# TTCTTATCCGCTGGGT-1                  1.811077                  3.460703
# TTGGACCATCTGGCAA-1                  1.805856                  0.921905
# TTGGCTCAATATGTGT-1                  6.599885                  0.577405
# TTGGGACGTAAGAGTT-1                  0.380761                  0.150268
#
#                     Cardiomyocytes A  Cardiomyocytes V  Dead cells  ...  \
# AAACAAGTATCTCCCA-1          0.966585          0.957577    0.032057  ...
# AAATCTAGCCCTGCTA-1          2.211748          6.051983    0.000899  ...
# AACACACGCTCGCCGC-1          0.259880          0.250789    1.111558  ...
# AACCCGAGCAGAATCG-1          1.415612          3.059782    0.028907  ...
# AACGCTGTTGCTGAAA-1          1.151912          2.008070    0.074700  ...
# ...                              ...               ...         ...  ...
# TTCCATCGACAGCGTG-1          1.431469          2.865060    0.003585  ...
# TTCTTATCCGCTGGGT-1          0.692393          0.961487    0.054763  ...
# TTGGACCATCTGGCAA-1          1.133352          3.162218    0.000987  ...
# TTGGCTCAATATGTGT-1          1.569070          0.945944    0.001474  ...
# TTGGGACGTAAGAGTT-1          0.156061          0.158762    0.000256  ...
#
#                     Monocytes  Myelin cells  Neuronal cells  Neutrophils  \
# AAACAAGTATCTCCCA-1   0.014995      0.037341        0.012612     0.176748
# AAATCTAGCCCTGCTA-1   0.005346      0.008824        0.000241     0.002465
# AACACACGCTCGCCGC-1   0.020472      0.003757        0.000917     3.023039
# AACCCGAGCAGAATCG-1   0.073597      0.098606        0.005960     0.009405
# AACGCTGTTGCTGAAA-1   0.012205      0.011596        0.006600     0.051325
# ...                       ...           ...             ...          ...
# TTCCATCGACAGCGTG-1   0.034189      0.056745        0.028837     0.008878
# TTCTTATCCGCTGGGT-1   0.025252      0.013749        0.000597     0.282793
# TTGGACCATCTGGCAA-1   0.010854      0.005333        0.000123     0.002703
# TTGGCTCAATATGTGT-1   0.019383      0.009804        0.096054     0.005117
# TTGGGACGTAAGAGTT-1   0.001106      0.001076        0.000116     0.000719
#
#                     Perivascular cells  Proliferating cells  \
# AAACAAGTATCTCCCA-1            0.334318             1.156188
# AAATCTAGCCCTGCTA-1            0.011399             0.004152
# AACACACGCTCGCCGC-1            0.477922             0.330480
# AACCCGAGCAGAATCG-1            0.076488             0.029143
# AACGCTGTTGCTGAAA-1            0.081835             0.764965
# ...                                ...                  ...
# TTCCATCGACAGCGTG-1            0.030286             0.020617
# TTCTTATCCGCTGGGT-1            0.493571             0.289658
# TTGGACCATCTGGCAA-1            0.009178             0.003351
# TTGGCTCAATATGTGT-1            0.039054             0.026064
# TTGGGACGTAAGAGTT-1            0.002559             0.001415
#
#                     Smooth muscle cells   T-cells  T-cells (il4/13)  \
# AAACAAGTATCTCCCA-1             0.176744  0.224892          0.056913
# AAATCTAGCCCTGCTA-1             0.009345  0.016358          0.004972
# AACACACGCTCGCCGC-1             0.012194  0.975087          0.242331
# AACCCGAGCAGAATCG-1             0.125278  0.036818          0.008829
# AACGCTGTTGCTGAAA-1             0.029850  0.087637          0.051183
# ...                                 ...       ...               ...
# TTCCATCGACAGCGTG-1             0.075244  0.027344          0.011732
# TTCTTATCCGCTGGGT-1             0.031470  0.390284          0.045844
# TTGGACCATCTGGCAA-1             0.009032  0.010798          0.003612
# TTGGCTCAATATGTGT-1             0.026637  0.014253          0.004481
# TTGGGACGTAAGAGTT-1             0.001890  0.002737          0.000578
#
#                     T-cells (proliferating)
# AAACAAGTATCTCCCA-1                 0.076203
# AAATCTAGCCCTGCTA-1                 0.007445
# AACACACGCTCGCCGC-1                 0.362085
# AACCCGAGCAGAATCG-1                 0.012349
# AACGCTGTTGCTGAAA-1                 0.022262
# ...                                     ...
# TTCCATCGACAGCGTG-1                 0.006016
# TTCTTATCCGCTGGGT-1                 0.198456
# TTGGACCATCTGGCAA-1                 0.003212
# TTGGCTCAATATGTGT-1                 0.007758
# TTGGGACGTAAGAGTT-1                 0.000463
#
# [180 rows x 45 columns]

# %%
adata_vis.obs[adata_vis.uns['mod']['factor_names']].to_csv('./output/cell2location/zebrafish_heart/SCD-VI-i001/cell2location_map/cell2location_prediction.csv')
